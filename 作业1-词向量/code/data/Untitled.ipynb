# %%
import pickle

# f = open('dict_word.pkl', 'rb')
# for line in f:
#     print(line)
word = pickle.load(open("vocab.en.pkl", 'rb'), encoding='utf-8')
print(word)
# Out:
# ['<START>', '<UNK>', '<END>', 'the', '.', ',', 'and', 'of', 'to', 'in', '"', 'a', 'is', 'that', "'s", 'on', 'china', 'for', 'has', 'with', 'this', 'have', 'will', 'by', 'be', 'as', 'are', 'it', 'people', 'taiwan', 'he', 'development', 'at', 'we', 'not', ':', 'said', 'an', 'chinese', 'countries', 'two', 'also', 'new', 'from', 'should', 'us', 'was', 'all', 'their', 'its', 'economic', 'relations', 'united', 'states', 'party', 'our', 'between', 'out', 'government', 'his', 'one', 'they', 'must', 'can', 'military', 'been', 'more', 'work', 'cooperation', 'important', 'national', 'which', 'up', 'world', 'only', 'other', 'some', 'but', "'", 'state', 'country', 'year', 'years', 'or', 'international', 'there', 'jiang', 'made', 'system', 'foreign', 'three', 'political', 'were', 'time', 'president', 'meeting', 'great', 'after', 'visit', 'first', 'issue', 'over', 'policy', 'security', 'had', 'about', 'li', 'make', 'zemin', 'no', 'situation', 'however', 'trade', 'social', 'these', 'since', 'economy
# ...
